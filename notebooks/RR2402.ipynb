# %% [markdown]
# # Example: RR2402
# This is an example that creates cruise tracks for [RR2402](https://doi.org/10.7284/910464).
#
# We'll start with package imports...

# %%
from datetime import datetime as dt
import pandas as pd
import openspace_rvdata.r2r2df as r2r
import openspace_rvdata.geocsv2geojson as g2g

import logging
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Pull data from R2R
# The first step is to pull data using the [R2R API](https://www.rvdata.us/about/technical-details/services/api) and generate a dataframe. We'll actually generate two: `df` for the data and `mdf` for metadata.

# %%
# url = r2r.get_r2r_url(cruise_id = "RR2402")
url = r2r.get_r2r_url(vessel_name = "Revelle")
mdf = r2r.get_cruise_metadata(url)
mdf

# %%
url = r2r.get_r2r_url(cruise_id = "NBP2101")
mdf = r2r.get_cruise_metadata(url)
mdf

# %%
r2r.get_cruise_nav(cruise_id = "NBP2205")

# %%
# r2r.get_cruise_nav(cruise_id = "RR2402")

# %%
# cruise_id_example = "RR2402"
# sampling_rate_example = "60min"

# %% [markdown]
# ## OpenSpace Asset Generation
# The [OpenSpace asset](https://docs.openspaceproject.com/releases-v0.20/creating-data-assets/asset-creation/assets.html#simple-example) we're creating has two parts: the keyframes (where the ship is) and the main asset file, which includes metadata about the mission. Both of these are in [Lua](https://www.lua.org/home.html), with the file suffix .asset.

# %% [markdown]
# ### Asset Generation from Dataframe

# %% [markdown]
# ### Keyframe Generation from Dataframe
# Each cruise gets its own keyframe asset. This is generated from the geoCSV file (created by R2R using https://github.com/rvdata/NavManager).

# %%
# df = pd.read_csv("temp/RR2402_1min.geoCSV", comment = '#')
# from datetime import datetime as dt
# df['datetime'] = pd.to_datetime(df['iso_time'])
# df.index = df['datetime']
# df = df.resample("60min").first()
# df = df.reset_index(drop=True)
# df.head()

# %% [markdown]
# ## Visualization Outside OpenSpace
# While we're at it, here are a couple of tools for visualizing ship trails that don't require OpenSpace.

# %% [markdown]
# ### Hypergram Visualization using Plotly Express
# [Plotly express](https://plotly.com/python/plotly-express/) makes it pretty straightforward to create HTML [hypergrams](https://worrydream.com/refs/Nelson_T_1974_-_Computer_Lib,_Dream_Machines.pdf). These can then be shared by email and opened locally in a browser, or embedded in a webpage.

# %% [markdown]
# ### Create GEOJSON
# If we just want to visualize the path itself, and don't need it animated, we can use the geocsv2geojson.py code in this folder to generate a GeoJSON file, then drag and drop that directly into OpenSpace (or QGIS, or Marble, or another mapping program of your choice). It'll look like this:
# ![image.png](attachment:544231ac-7dd6-4ae0-a497-a44965d851e1.png)

# %%
import os
cruise_id = "RR1105"
any(cruise_id in filename for filename in os.listdir("tmp/"))

# url = r2r.get_r2r_url(cruise_id = "RR2402")
url = r2r.get_r2r_url(vessel_name = "Revelle")
mdf = r2r.get_cruise_metadata(url)
mdf


for cruise_id in mdf.cruise_id:
    # todo: add check for if cruise_id is already covered in tmp directory
    is_in_filename = any(cruise_id in filename for filename in os.listdir("tmp/"))
    if is_in_filename:
        print("Got a file for " + cruise_id + "; moving on.")
        continue
    else:
        try:
            print("Gonna pull data for " + cruise_id)
        except:
            print("Ran into an issue with " + cruise_id)
            continue
# Out:
# Gonna pull data for RR2501
# Got a file for RR2415; moving on.
# Got a file for RR2414; moving on.
# Got a file for RR2413; moving on.
# Got a file for RR2412; moving on.
# Got a file for RR2411; moving on.
# Got a file for RR2410; moving on.
# Got a file for RR2409; moving on.
# Got a file for RR2408; moving on.
# Got a file for RR2407; moving on.
# Got a file for RR2406; moving on.
# Got a file for RR2405; moving on.
# Got a file for RR2404; moving on.
# Got a file for RR2403; moving on.
# Got a file for RR2402; moving on.
# Gonna pull data for RR2401
# Got a file for RR2312; moving on.
# Got a file for RR2311; moving on.
# Got a file for RR2310; moving on.
# Got a file for RR2309; moving on.
# Got a file for RR2308; moving on.
# Got a file for RR2307; moving on.
# Got a file for RR2306; moving on.
# Got a file for RR2305; moving on.
# Gonna pull data for RR2304
# Got a file for RR2303; moving on.
# Got a file for RR2302; moving on.
# Got a file for RR2301; moving on.
# Got a file for RR2214; moving on.
# Got a file for RR2213; moving on.
# Got a file for RR2212; moving on.
# Got a file for RR2211; moving on.
# Got a file for RR2210; moving on.
# Got a file for RR2209; moving on.
# Got a file for RR2208; moving on.
# Got a file for RR2207; moving on.
# Got a file for RR2206; moving on.
# Got a file for RR2205; moving on.
# Got a file for RR2204; moving on.
# Got a file for RR2203; moving on.
# Got a file for RR2202; moving on.
# Got a file for RR2201; moving on.
# Got a file for RR2108; moving on.
# Got a file for RR2107; moving on.
# Got a file for RR2106; moving on.
# Got a file for RR2105; moving on.
# Got a file for RR2104; moving on.
# Got a file for RR2103; moving on.
# Got a file for RR2102; moving on.
# Got a file for RR2101; moving on.
# Got a file for RR2004; moving on.
# Got a file for RR2003; moving on.
# Gonna pull data for RR2002
# Gonna pull data for RR2001
# Gonna pull data for RR1905
# Got a file for RR1904; moving on.
# Got a file for RR1903; moving on.
# Got a file for RR1902; moving on.
# Got a file for RR1901; moving on.
# Got a file for RR1817; moving on.
# Got a file for RR1816; moving on.
# Got a file for RR1815; moving on.
# Got a file for RR1814; moving on.
# Got a file for RR1813; moving on.
# Got a file for RR1812; moving on.
# Got a file for RR1811; moving on.
# Gonna pull data for RR1810
# Gonna pull data for RR1809
# Got a file for RR1808; moving on.
# Got a file for RR1807; moving on.
# Got a file for RR1806; moving on.
# Got a file for RR1805; moving on.
# Got a file for RR1804; moving on.
# Got a file for RR1803; moving on.
# Got a file for RR1802; moving on.
# Got a file for RR1801; moving on.
# Got a file for RR1722; moving on.
# Got a file for RR1720; moving on.
# Got a file for RR1719; moving on.
# Got a file for RR1718; moving on.
# Got a file for RR1717; moving on.
# Got a file for RR1716; moving on.
# Got a file for RR1715; moving on.
# Got a file for RR1714; moving on.
# Got a file for RR1713; moving on.
# Got a file for RR1712; moving on.
# Got a file for RR1711; moving on.
# Got a file for RR1710; moving on.
# Got a file for RR1709; moving on.
# Got a file for RR1708; moving on.
# Got a file for RR1707; moving on.
# Got a file for RR1706; moving on.
# Got a file for RR1705; moving on.
# Got a file for RR1704; moving on.
# Got a file for RR1703; moving on.
# Got a file for RR1702; moving on.
# Got a file for RR1701; moving on.
# Got a file for RR1614; moving on.
# Got a file for RR1613; moving on.
# Got a file for RR1612; moving on.
# Got a file for RR1611; moving on.
# Got a file for RR1610; moving on.
# Got a file for RR1609; moving on.
# Got a file for RR1608; moving on.
# Got a file for RR1607; moving on.
# Got a file for RR1606; moving on.
# Got a file for RR1605; moving on.
# Got a file for RR1604; moving on.
# Got a file for RR1603; moving on.
# Got a file for RR1602; moving on.
# Got a file for RR1601; moving on.
# Got a file for RR1516; moving on.
# Got a file for RR1515; moving on.
# Got a file for RR1514; moving on.
# Got a file for RR1513; moving on.
# Got a file for RR1512; moving on.
# Got a file for RR1511; moving on.
# Got a file for RR1510; moving on.
# Got a file for RR1509; moving on.
# Got a file for RR1508; moving on.
# Got a file for RR1507; moving on.
# Got a file for RR1506; moving on.
# Got a file for RR1505; moving on.
# Got a file for RR1504; moving on.
# Got a file for RR1503; moving on.
# Got a file for RR1502; moving on.
# Got a file for RR1501; moving on.
# Got a file for RR1413; moving on.
# Got a file for RR1412; moving on.
# Gonna pull data for RR1411
# Got a file for RR1407; moving on.
# Got a file for RR1406; moving on.
# Got a file for RR1405; moving on.
# Got a file for RR1404; moving on.
# Got a file for RR1403; moving on.
# Got a file for RR1402; moving on.
# Got a file for RR1401; moving on.
# Got a file for RR1319; moving on.
# Got a file for RR1318; moving on.
# Got a file for RR1317; moving on.
# Got a file for RR1316; moving on.
# Got a file for RR1315; moving on.
# Gonna pull data for RR1314
# Got a file for RR1313; moving on.
# Got a file for RR1312; moving on.
# Got a file for RR1311; moving on.
# Got a file for RR1310; moving on.
# Got a file for RR1309; moving on.
# Got a file for RR1308; moving on.
# Got a file for RR1307; moving on.
# Got a file for RR1306; moving on.
# Got a file for RR1305; moving on.
# Got a file for RR1304; moving on.
# Got a file for RR1303; moving on.
# Got a file for RR1302; moving on.
# Got a file for RR1301; moving on.
# Got a file for RR1214; moving on.
# Got a file for RR1213; moving on.
# Got a file for RR1212; moving on.
# Got a file for RR1211; moving on.
# Got a file for RR1210; moving on.
# Got a file for RR1209; moving on.
# Got a file for RR1208; moving on.
# Gonna pull data for RR1207
# Got a file for RR1206; moving on.
# Got a file for RR1205; moving on.
# Got a file for RR1204; moving on.
# Got a file for RR1203; moving on.
# Got a file for RR1202; moving on.
# Got a file for RR1201; moving on.
# Got a file for RR1117; moving on.
# Got a file for RR1116; moving on.
# Got a file for RR1115; moving on.
# Got a file for RR1114; moving on.
# Gonna pull data for RR1113
# Got a file for RR1112; moving on.
# Got a file for RR1111; moving on.
# Got a file for RR1110; moving on.
# Got a file for RR1109; moving on.
# Got a file for RR1108; moving on.
# Gonna pull data for RR1107
# Got a file for RR1106; moving on.
# Got a file for RR1105; moving on.
# Gonna pull data for RR1104
# Gonna pull data for RR1103
# Gonna pull data for RR1102
# Gonna pull data for RR1101
# Got a file for RR1016; moving on.
# Gonna pull data for RR1015
# Gonna pull data for RR1014
# Gonna pull data for RR1013
# Gonna pull data for RR1012
# Gonna pull data for RR1011
# Gonna pull data for RR1010
# Gonna pull data for RR1009
# Gonna pull data for RR1008
# Gonna pull data for RR1007
# Gonna pull data for RR1006
# Gonna pull data for RR1005
# Gonna pull data for RR1004
# Gonna pull data for RR1003
# Gonna pull data for RR1002
# Gonna pull data for RR1001
# Gonna pull data for RR0917
# Gonna pull data for RR0916
# Gonna pull data for RR0915
# Gonna pull data for RR0914
# Gonna pull data for RR0913
# Gonna pull data for RR0912
# Gonna pull data for RR0911
# Gonna pull data for RR0910
# Gonna pull data for RR0909
# Gonna pull data for RR0908
# Gonna pull data for RR0907
# Gonna pull data for RR0906
# Gonna pull data for RR0905
# Gonna pull data for RR0904
# Gonna pull data for RR0903
# Gonna pull data for RR0902
# Gonna pull data for RR0901
# Gonna pull data for KNOX22RR
# Gonna pull data for KNOX21RR
# Gonna pull data for KNOX20RR
# Gonna pull data for KNOX19RR
# Gonna pull data for KNOX18RR
# Gonna pull data for KNOX17RR
# Gonna pull data for KNOX16RR
# Gonna pull data for KNOX15RR
# Gonna pull data for KNOX14RR
# Gonna pull data for KNOX13RR
# Gonna pull data for KNOX12RR
# Gonna pull data for KNOX11RR
# Gonna pull data for KNOX10RR
# Gonna pull data for KNOX09RR
# Gonna pull data for KNOX08RR
# Gonna pull data for KNOX07RR
# Gonna pull data for KNOX06RR
# Gonna pull data for KNOX05RR
# Gonna pull data for KNOX04RR
# Gonna pull data for KNOX03RR
# Gonna pull data for KNOX02RR
# Gonna pull data for KNOX01RR
# Gonna pull data for CA0607RR
# Gonna pull data for CA0606RR
# Gonna pull data for CA0605RR
# Gonna pull data for CA0604RR
# Gonna pull data for CA0603RR
# Gonna pull data for CA0602RR
# Gonna pull data for CA0601RR
# Gonna pull data for AMAT09RR
# Gonna pull data for AMAT08RR
# Gonna pull data for AMAT07RR
# Gonna pull data for AMAT06RR
# Gonna pull data for AMAT05RR
# Gonna pull data for AMAT04RR
# Gonna pull data for AMAT03RR
# Gonna pull data for AMAT02RR
# Gonna pull data for AMAT01RR
# Gonna pull data for SANQ01RR
# Gonna pull data for ZHNG10RR
# Gonna pull data for ZHNG09RR
# Gonna pull data for ZHNG08RR
# Gonna pull data for ZHNG07RR
# Gonna pull data for ZHNG06RR
# Gonna pull data for ZHNG05RR
# Gonna pull data for ZHNG04RR
# Gonna pull data for ZHNG03RR
# Gonna pull data for ZHNG02RR
# Gonna pull data for ZHNG01RR
# Gonna pull data for CSIO02RR
# Gonna pull data for CSIO01RR
# Gonna pull data for KRUS06RR
# Gonna pull data for KRUS05RR
# Gonna pull data for KRUS04RR
# Gonna pull data for KRUS03RR
# Gonna pull data for KRUS02RR
# Gonna pull data for KRUS01RR
# Gonna pull data for DANA08RR
# Gonna pull data for DANA07RR
# Gonna pull data for DANA06RR
# Gonna pull data for DANA05RR
# Gonna pull data for DANA04RR
# Gonna pull data for DANA03RR
# Gonna pull data for DANA02RR
# Gonna pull data for DANA01RR
# Gonna pull data for CNTL15RR
# Gonna pull data for CNTL14RR
# Gonna pull data for CNTL13RR
# Gonna pull data for CNTL12RR
# Gonna pull data for CNTL11RR
# Gonna pull data for CNTL10RR
# Gonna pull data for CNTL09RR
# Gonna pull data for CNTL08RR
# Gonna pull data for CNTL07RR
# Gonna pull data for CNTL06RR
# Gonna pull data for CNTL05RR
# Gonna pull data for CNTL04RR
# Gonna pull data for CNTL03RR
# Gonna pull data for CNTL02RR
# Gonna pull data for CNTL01RR
# Gonna pull data for LPRS07RR
# Gonna pull data for LPRS06RR
# Gonna pull data for LPRS05RR
# Gonna pull data for LPRS04RR
# Gonna pull data for LPRS03RR
# Gonna pull data for LPRS02RR
# Gonna pull data for LPRS01RR
# Gonna pull data for DRFT16RR
# Gonna pull data for DRFT15RR
# Gonna pull data for DRFT14RR
# Gonna pull data for DRFT13RR
# Gonna pull data for DRFT12RR
# Gonna pull data for DRFT11RR
# Gonna pull data for DRFT10RR
# Gonna pull data for DRFT09RR
# Gonna pull data for DRFT08RR
# Gonna pull data for DRFT07RR
# Gonna pull data for DRFT06RR
# Gonna pull data for DRFT05RR
# Gonna pull data for DRFT04RR
# Gonna pull data for DRFT03RR
# Gonna pull data for DRFT02RR
# Gonna pull data for DRFT01RR
# Gonna pull data for SEAW06RR
# Gonna pull data for SEAW05RR
# Gonna pull data for SEAW04RR
# Gonna pull data for SEAW03RR
# Gonna pull data for SEAW02RR
# Gonna pull data for SEAW01RR
# Gonna pull data for NECR06RR
# Gonna pull data for NECR05RR
# Gonna pull data for NECR04RR
# Gonna pull data for NECR03RR
# Gonna pull data for NECR02RR
# Gonna pull data for NECR01RR
# Gonna pull data for NALU01RR
# Gonna pull data for HNRO18RR
# Gonna pull data for HNRO17RR
# Gonna pull data for HNRO16RR
# Gonna pull data for HNRO15RR
# Gonna pull data for HNRO14RR
# Gonna pull data for HNRO13RR
# Gonna pull data for HNRO12RR
# Gonna pull data for HNRO11RR
# Gonna pull data for HNRO07RR
# Gonna pull data for HNRO06RR
# Gonna pull data for HNRO05RR
# Gonna pull data for HNRO04RR
# Gonna pull data for HNRO01RR
# Gonna pull data for ACLV01RR
# Gonna pull data for SNKX01RR
# Gonna pull data for 981107RR
# Gonna pull data for ALAR02RR
# Gonna pull data for ALAR01RR
# Gonna pull data for KIWI14RR
# Gonna pull data for KIWI12RR
# Gonna pull data for KIWI11RR
# Gonna pull data for KIWI10RR
# Gonna pull data for KIWI09RR
# Gonna pull data for KIWI08RR
# Gonna pull data for KIWI07RR
# Gonna pull data for KIWI06RR
# Gonna pull data for KIWI05RR
# Gonna pull data for KIWI04RR
# Gonna pull data for KIWI03RR
# Gonna pull data for KIWI02RR
# Gonna pull data for KIWI01RR
# Gonna pull data for TANR01RR
# Gonna pull data for GENE04RR
# Gonna pull data for GENE03RR
# Gonna pull data for GENE02RR
# Gonna pull data for GENE01RR
# Gonna pull data for REVT03RR
# Gonna pull data for REVT02RR
# Gonna pull data for CALF03RR
# Gonna pull data for CALF01RR
# Gonna pull data for REVT01RR
# Gonna pull data for DELV02RR
# Gonna pull data for DELV01RR

# %%
url = r2r.get_r2r_url(vessel_name = "Revelle")
mdf = r2r.get_cruise_metadata(url)
import os

for cruise_id in mdf.cruise_id:
    # todo: add check for if cruise_id is already covered in tmp directory
    is_in_filename = any(cruise_id in filename for filename in os.listdir("tmp/"))
    if is_in_filename:
        print("Got a file for " + cruise_id + "; moving on.")
        continue
    else:
        try:
            print("Pulling data for" + cruise_id)
            r2r.get_cruise_nav(cruise_id, "60min")
        except:
            print("Ran into an issue with " + cruise_id)
            continue


# from pathlib import Path
# for file_path in Path("tmp").rglob('*_1min.geoCSV'):
#     if file_path.is_file():
#         fname = str(file_path.stem)
#         g2g.convert_geocsv_to_geojson(file_path, "tmp/"+fname+".geoJSON")
# Out:
# Pulling data forRR2501
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR2501
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 16 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 does not have a valid 'product_info' string (found: None).
# Processing item 3 from 'data' list...
#   Item 3 does not have a valid 'product_info' string (found: None).
# Processing item 4 from 'data' list...
#   Item 4 does not have a valid 'product_info' string (found: None).
# Processing item 5 from 'data' list...
#   Item 5 does not have a valid 'product_info' string (found: None).
# Processing item 6 from 'data' list...
#   Item 6 does not have a valid 'product_info' string (found: None).
# Processing item 7 from 'data' list...
#   Item 7 does not have a valid 'product_info' string (found: None).
# Processing item 8 from 'data' list...
#   Item 8 does not have a valid 'product_info' string (found: None).
# Processing item 9 from 'data' list...
#   Item 9 does not have a valid 'product_info' string (found: None).
# Processing item 10 from 'data' list...
#   Item 10 does not have a valid 'product_info' string (found: None).
# Processing item 11 from 'data' list...
#   Item 11 does not have a valid 'product_info' string (found: None).
# Processing item 12 from 'data' list...
#   Item 12 does not have a valid 'product_info' string (found: None).
# Processing item 13 from 'data' list...
#   Item 13 does not have a valid 'product_info' string (found: None).
# Processing item 14 from 'data' list...
#   Item 14 does not have a valid 'product_info' string (found: None).
# Processing item 15 from 'data' list...
#   Item 15 does not have a valid 'product_info' string (found: None).
# Processing item 16 from 'data' list...
#   Item 16 does not have a valid 'product_info' string (found: None).
# DEBUG: No 'Navigation' product type found within any 'product_info' in the API response for cruise_id: RR2501
# DEBUG: No 'product_info' fields found or all failed to parse for any product_type_name.
# Ran into an issue with RR2501
# Got a file for RR2415; moving on.
# Got a file for RR2414; moving on.
# Got a file for RR2413; moving on.
# Got a file for RR2412; moving on.
# Got a file for RR2411; moving on.
# Got a file for RR2410; moving on.
# Got a file for RR2409; moving on.
# Got a file for RR2408; moving on.
# Got a file for RR2407; moving on.
# Got a file for RR2406; moving on.
# Got a file for RR2405; moving on.
# Got a file for RR2404; moving on.
# Got a file for RR2403; moving on.
# Got a file for RR2402; moving on.
# Pulling data forRR2401
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR2401
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 6 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 does not have a valid 'product_info' string (found: None).
# Processing item 3 from 'data' list...
#   Item 3 does not have a valid 'product_info' string (found: None).
# Processing item 4 from 'data' list...
#   Item 4 does not have a valid 'product_info' string (found: None).
# Processing item 5 from 'data' list...
#   Item 5 does not have a valid 'product_info' string (found: None).
# Processing item 6 from 'data' list...
#   Item 6 does not have a valid 'product_info' string (found: None).
# DEBUG: No 'Navigation' product type found within any 'product_info' in the API response for cruise_id: RR2401
# DEBUG: No 'product_info' fields found or all failed to parse for any product_type_name.
# Ran into an issue with RR2401
# Got a file for RR2312; moving on.
# Got a file for RR2311; moving on.
# Got a file for RR2310; moving on.
# Got a file for RR2309; moving on.
# Got a file for RR2308; moving on.
# Got a file for RR2307; moving on.
# Got a file for RR2306; moving on.
# Got a file for RR2305; moving on.
# Pulling data forRR2304
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR2304
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR2304
# Got a file for RR2303; moving on.
# Got a file for RR2302; moving on.
# Got a file for RR2301; moving on.
# Got a file for RR2214; moving on.
# Got a file for RR2213; moving on.
# Got a file for RR2212; moving on.
# Got a file for RR2211; moving on.
# Got a file for RR2210; moving on.
# Got a file for RR2209; moving on.
# Got a file for RR2208; moving on.
# Got a file for RR2207; moving on.
# Got a file for RR2206; moving on.
# Got a file for RR2205; moving on.
# Got a file for RR2204; moving on.
# Got a file for RR2203; moving on.
# Got a file for RR2202; moving on.
# Got a file for RR2201; moving on.
# Got a file for RR2108; moving on.
# Got a file for RR2107; moving on.
# Got a file for RR2106; moving on.
# Got a file for RR2105; moving on.
# Got a file for RR2104; moving on.
# Got a file for RR2103; moving on.
# Got a file for RR2102; moving on.
# Got a file for RR2101; moving on.
# Got a file for RR2004; moving on.
# Got a file for RR2003; moving on.
# Pulling data forRR2002
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR2002
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 5 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 does not have a valid 'product_info' string (found: None).
# Processing item 3 from 'data' list...
#   Item 3 does not have a valid 'product_info' string (found: None).
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'JGOFS'
# Processing item 5 from 'data' list...
#   Item 5 does not have a valid 'product_info' string (found: None).
# DEBUG: No 'Navigation' product type found within any 'product_info' in the API response for cruise_id: RR2002
# DEBUG: All product types found were: ['JGOFS']
# Ran into an issue with RR2002
# Pulling data forRR2001
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR2001
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR2001
# Pulling data forRR1905
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1905
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1905
# Got a file for RR1904; moving on.
# Got a file for RR1903; moving on.
# Got a file for RR1902; moving on.
# Got a file for RR1901; moving on.
# Got a file for RR1817; moving on.
# Got a file for RR1816; moving on.
# Got a file for RR1815; moving on.
# Got a file for RR1814; moving on.
# Got a file for RR1813; moving on.
# Got a file for RR1812; moving on.
# Got a file for RR1811; moving on.
# Pulling data forRR1810
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1810
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1810
# Pulling data forRR1809
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1809
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1809
# Got a file for RR1808; moving on.
# Got a file for RR1807; moving on.
# Got a file for RR1806; moving on.
# Got a file for RR1805; moving on.
# Got a file for RR1804; moving on.
# Got a file for RR1803; moving on.
# Got a file for RR1802; moving on.
# Got a file for RR1801; moving on.
# Got a file for RR1722; moving on.
# Got a file for RR1720; moving on.
# Got a file for RR1719; moving on.
# Got a file for RR1718; moving on.
# Got a file for RR1717; moving on.
# Got a file for RR1716; moving on.
# Got a file for RR1715; moving on.
# Got a file for RR1714; moving on.
# Got a file for RR1713; moving on.
# Got a file for RR1712; moving on.
# Got a file for RR1711; moving on.
# Got a file for RR1710; moving on.
# Got a file for RR1709; moving on.
# Got a file for RR1708; moving on.
# Got a file for RR1707; moving on.
# Got a file for RR1706; moving on.
# Got a file for RR1705; moving on.
# Got a file for RR1704; moving on.
# Got a file for RR1703; moving on.
# Got a file for RR1702; moving on.
# Got a file for RR1701; moving on.
# Got a file for RR1614; moving on.
# Got a file for RR1613; moving on.
# Got a file for RR1612; moving on.
# Got a file for RR1611; moving on.
# Got a file for RR1610; moving on.
# Got a file for RR1609; moving on.
# Got a file for RR1608; moving on.
# Got a file for RR1607; moving on.
# Got a file for RR1606; moving on.
# Got a file for RR1605; moving on.
# Got a file for RR1604; moving on.
# Got a file for RR1603; moving on.
# Got a file for RR1602; moving on.
# Got a file for RR1601; moving on.
# Got a file for RR1516; moving on.
# Got a file for RR1515; moving on.
# Got a file for RR1514; moving on.
# Got a file for RR1513; moving on.
# Got a file for RR1512; moving on.
# Got a file for RR1511; moving on.
# Got a file for RR1510; moving on.
# Got a file for RR1509; moving on.
# Got a file for RR1508; moving on.
# Got a file for RR1507; moving on.
# Got a file for RR1506; moving on.
# Got a file for RR1505; moving on.
# Got a file for RR1504; moving on.
# Got a file for RR1503; moving on.
# Got a file for RR1502; moving on.
# Got a file for RR1501; moving on.
# Got a file for RR1413; moving on.
# Got a file for RR1412; moving on.
# Pulling data forRR1411
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1411
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1411
# Got a file for RR1407; moving on.
# Got a file for RR1406; moving on.
# Got a file for RR1405; moving on.
# Got a file for RR1404; moving on.
# Got a file for RR1403; moving on.
# Got a file for RR1402; moving on.
# Got a file for RR1401; moving on.
# Got a file for RR1319; moving on.
# Got a file for RR1318; moving on.
# Got a file for RR1317; moving on.
# Got a file for RR1316; moving on.
# Got a file for RR1315; moving on.
# Pulling data forRR1314
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1314
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1314
# Got a file for RR1313; moving on.
# Got a file for RR1312; moving on.
# Got a file for RR1311; moving on.
# Got a file for RR1310; moving on.
# Got a file for RR1309; moving on.
# Got a file for RR1308; moving on.
# Got a file for RR1307; moving on.
# Got a file for RR1306; moving on.
# Got a file for RR1305; moving on.
# Got a file for RR1304; moving on.
# Got a file for RR1303; moving on.
# Got a file for RR1302; moving on.
# Got a file for RR1301; moving on.
# Got a file for RR1214; moving on.
# Got a file for RR1213; moving on.
# Got a file for RR1212; moving on.
# Got a file for RR1211; moving on.
# Got a file for RR1210; moving on.
# Got a file for RR1209; moving on.
# Got a file for RR1208; moving on.
# Pulling data forRR1207
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1207
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1207
# Got a file for RR1206; moving on.
# Got a file for RR1205; moving on.
# Got a file for RR1204; moving on.
# Got a file for RR1203; moving on.
# Got a file for RR1202; moving on.
# Got a file for RR1201; moving on.
# Got a file for RR1117; moving on.
# Got a file for RR1116; moving on.
# Got a file for RR1115; moving on.
# Got a file for RR1114; moving on.
# Pulling data forRR1113
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1113
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1113
# Got a file for RR1112; moving on.
# Got a file for RR1111; moving on.
# Got a file for RR1110; moving on.
# Got a file for RR1109; moving on.
# Got a file for RR1108; moving on.
# Pulling data forRR1107
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1107
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 does not have a valid 'product_info' string (found: None).
# Processing item 4 from 'data' list...
#   Item 4 does not have a valid 'product_info' string (found: None).
# Processing item 5 from 'data' list...
#   Item 5 does not have a valid 'product_info' string (found: None).
# Processing item 6 from 'data' list...
#   Item 6 does not have a valid 'product_info' string (found: None).
# Processing item 7 from 'data' list...
#   Item 7 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Gravity'
# Processing item 8 from 'data' list...
#   Item 8 does not have a valid 'product_info' string (found: None).
# Processing item 9 from 'data' list...
#   Item 9 does not have a valid 'product_info' string (found: None).
# Processing item 10 from 'data' list...
#   Item 10 does not have a valid 'product_info' string (found: None).
# Processing item 11 from 'data' list...
#   Item 11 does not have a valid 'product_info' string (found: None).
# DEBUG: No 'Navigation' product type found within any 'product_info' in the API response for cruise_id: RR1107
# DEBUG: All product types found were: ['CTD', 'Gravity']
# Ran into an issue with RR1107
# Got a file for RR1106; moving on.
# Got a file for RR1105; moving on.
# Pulling data forRR1104
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1104
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 7 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 3 from 'data' list...
#   Item 3 does not have a valid 'product_info' string (found: None).
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/RR1104_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1104_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/RR1104.geoCSV
# Could not download RR1104.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/RR1104.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132120/4.6/data/0-data/RR1104_604175_r2rnav/data/RR1104.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132120/4.6/data/0-data/RR1104_604175_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132120/4.6/data/0-data/RR1104_604175_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132120/data/0-data/RR1104_604175_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132120/4.6/data/0-data/RR1104_604175_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1104_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1103
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1103
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 14 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 3 from 'data' list...
#   Item 3 does not have a valid 'product_info' string (found: None).
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/RR1103_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1103_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/RR1103.geoCSV
# Could not download RR1103.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/RR1103.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132119/4.6/data/0-data/RR1103_604174_r2rnav/data/RR1103.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132119/4.6/data/0-data/RR1103_604174_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132119/4.6/data/0-data/RR1103_604174_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0132119/data/0-data/RR1103_604174_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0132119/4.6/data/0-data/RR1103_604174_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1103_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1102
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1102
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1102
# Pulling data forRR1101
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1101
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with RR1101
# Got a file for RR1016; moving on.
# Pulling data forRR1015
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1015
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/RR1015_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1015_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/RR1015.geoCSV
# Could not download RR1015.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/RR1015.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129833/4.6/data/0-data/RR1015_608306_r2rnav/data/RR1015.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129833/4.6/data/0-data/RR1015_608306_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129833/4.6/data/0-data/RR1015_608306_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129833/data/0-data/RR1015_608306_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129833/4.6/data/0-data/RR1015_608306_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1015_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1014
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1014
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/RR1014_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1014_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/RR1014.geoCSV
# Could not download RR1014.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/RR1014.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089642/4.6/data/0-data/RR1014_608305_r2rnav/data/RR1014.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089642/4.6/data/0-data/RR1014_608305_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089642/4.6/data/0-data/RR1014_608305_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089642/data/0-data/RR1014_608305_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089642/4.6/data/0-data/RR1014_608305_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1014_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1013
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1013
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/RR1013_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1013_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/RR1013.geoCSV
# Could not download RR1013.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/RR1013.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089641/4.6/data/0-data/RR1013_608304_r2rnav/data/RR1013.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089641/4.6/data/0-data/RR1013_608304_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089641/4.6/data/0-data/RR1013_608304_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089641/data/0-data/RR1013_608304_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089641/4.6/data/0-data/RR1013_608304_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1013_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1012
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1012
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/RR1012_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1012_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/RR1012.geoCSV
# Could not download RR1012.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/RR1012.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089640/4.6/data/0-data/RR1012_608303_r2rnav/data/RR1012.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089640/4.6/data/0-data/RR1012_608303_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089640/4.6/data/0-data/RR1012_608303_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089640/data/0-data/RR1012_608303_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089640/4.6/data/0-data/RR1012_608303_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1012_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1011
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1011
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 10 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/RR1011_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1011_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/RR1011.geoCSV
# Could not download RR1011.geoCSV from https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/RR1011.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0134538/4.6/data/0-data/RR1011_608302_r2rnav/data/RR1011.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0134538/4.6/data/0-data/RR1011_608302_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0134538/4.6/data/0-data/RR1011_608302_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0134538/data/0-data/RR1011_608302_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0079/0134538/4.6/data/0-data/RR1011_608302_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1011_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1010
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1010
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/RR1010_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1010_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/RR1010.geoCSV
# Could not download RR1010.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/RR1010.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129832/6.8/data/0-data/RR1010_608301_r2rnav/data/RR1010.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129832/6.8/data/0-data/RR1010_608301_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129832/6.8/data/0-data/RR1010_608301_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0129832/data/0-data/RR1010_608301_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0077/0129832/6.8/data/0-data/RR1010_608301_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1010_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1009
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1009
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/RR1009_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1009_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/RR1009.geoCSV
# Could not download RR1009.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/RR1009.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089639/4.6/data/0-data/RR1009_608300_r2rnav/data/RR1009.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089639/4.6/data/0-data/RR1009_608300_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089639/4.6/data/0-data/RR1009_608300_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089639/data/0-data/RR1009_608300_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089639/4.6/data/0-data/RR1009_608300_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1009_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1008
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1008
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/RR1008_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1008_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/RR1008.geoCSV
# Could not download RR1008.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/RR1008.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089638/4.6/data/0-data/RR1008_608299_r2rnav/data/RR1008.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/navigation.geoCSV
# Could not download navigation.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/navigation.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089638/4.6/data/0-data/RR1008_608299_r2rnav/data/navigation.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/data.geoCSV
# Could not download data.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/data.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089638/4.6/data/0-data/RR1008_608299_r2rnav/data/data.geoCSV. Trying next possible file.
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/metadata.geoCSV
# Could not download metadata.geoCSV from https://www.ncei.noaa.gov/archive/accession/0089638/data/0-data/RR1008_608299_r2rnav//data/metadata.geoCSV: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/data/oceans/archive/arc0044/0089638/4.6/data/0-data/RR1008_608299_r2rnav/data/metadata.geoCSV. Trying next possible file.
# Reading data from selected .geoCSV file: RR1008_1min.geoCSV
# Resampling data to: 60min
# Pulling data forRR1007
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/RR1007
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Found 11 items in 'data'.
# Processing item 1 from 'data' list...
#   Item 1 does not have a valid 'product_info' string (found: None).
# Processing item 2 from 'data' list...
#   Item 2 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'CTD'
# Processing item 3 from 'data' list...
#   Item 3 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Expendableprobe'
# Processing item 4 from 'data' list...
#   Item 4 has 'product_info'. Parsed 1 product details.
#     Found product_type_name: 'Navigation'
#   ---> Found 'Navigation' product type within item 4!
# Processing data from: https://www.ncei.noaa.gov/archive/accession/0089637/data/0-data/RR1007_608298_r2rnav/
# URL does not end with .tar.gz. Attempting to check for /data subdirectory for .geoCSV files...
# Checking for .geoCSV files in: https://www.ncei.noaa.gov/archive/accession/0089637/data/0-data/RR1007_608298_r2rnav//data/
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089637/data/0-data/RR1007_608298_r2rnav//data/RR1007_1min.geoCSV
# Successfully downloaded .geoCSV file: RR1007_1min.geoCSV
# Attempting to download: https://www.ncei.noaa.gov/archive/accession/0089637/data/0-data/RR1007_608298_r2rnav//data/RR1007.geoCSV
# ...
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT13RR
# Pulling data forDRFT12RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT12RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT12RR
# Pulling data forDRFT11RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT11RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT11RR
# Pulling data forDRFT10RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT10RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT10RR
# Pulling data forDRFT09RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT09RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT09RR
# Pulling data forDRFT08RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT08RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT08RR
# Pulling data forDRFT07RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT07RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT07RR
# Pulling data forDRFT06RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT06RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT06RR
# Pulling data forDRFT05RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT05RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT05RR
# Pulling data forDRFT04RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT04RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT04RR
# Pulling data forDRFT03RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT03RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT03RR
# Pulling data forDRFT02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT02RR
# Pulling data forDRFT01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DRFT01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DRFT01RR
# Pulling data forSEAW06RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/SEAW06RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with SEAW06RR
# Pulling data forSEAW05RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/SEAW05RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with SEAW05RR
# Pulling data forSEAW04RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/SEAW04RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with SEAW04RR
# Pulling data forSEAW03RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/SEAW03RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with SEAW03RR
# Pulling data forSEAW02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/SEAW02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with SEAW02RR
# Pulling data forSEAW01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/SEAW01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with SEAW01RR
# Pulling data forNECR06RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/NECR06RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with NECR06RR
# Pulling data forNECR05RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/NECR05RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with NECR05RR
# Pulling data forNECR04RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/NECR04RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with NECR04RR
# Pulling data forNECR03RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/NECR03RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with NECR03RR
# Pulling data forNECR02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/NECR02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with NECR02RR
# Pulling data forNECR01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/NECR01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with NECR01RR
# Pulling data forNALU01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/NALU01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with NALU01RR
# Pulling data forHNRO18RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO18RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO18RR
# Pulling data forHNRO17RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO17RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO17RR
# Pulling data forHNRO16RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO16RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO16RR
# Pulling data forHNRO15RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO15RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO15RR
# Pulling data forHNRO14RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO14RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO14RR
# Pulling data forHNRO13RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO13RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO13RR
# Pulling data forHNRO12RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO12RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO12RR
# Pulling data forHNRO11RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO11RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO11RR
# Pulling data forHNRO07RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO07RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO07RR
# Pulling data forHNRO06RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO06RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO06RR
# Pulling data forHNRO05RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO05RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO05RR
# Pulling data forHNRO04RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO04RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO04RR
# Pulling data forHNRO01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/HNRO01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with HNRO01RR
# Pulling data forACLV01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/ACLV01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with ACLV01RR
# Pulling data forSNKX01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/SNKX01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with SNKX01RR
# Pulling data for981107RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/981107RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with 981107RR
# Pulling data forALAR02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/ALAR02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with ALAR02RR
# Pulling data forALAR01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/ALAR01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with ALAR01RR
# Pulling data forKIWI14RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI14RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI14RR
# Pulling data forKIWI12RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI12RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI12RR
# Pulling data forKIWI11RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI11RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI11RR
# Pulling data forKIWI10RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI10RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI10RR
# Pulling data forKIWI09RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI09RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI09RR
# Pulling data forKIWI08RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI08RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI08RR
# Pulling data forKIWI07RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI07RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI07RR
# Pulling data forKIWI06RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI06RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI06RR
# Pulling data forKIWI05RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI05RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI05RR
# Pulling data forKIWI04RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI04RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI04RR
# Pulling data forKIWI03RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI03RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI03RR
# Pulling data forKIWI02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI02RR
# Pulling data forKIWI01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/KIWI01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with KIWI01RR
# Pulling data forTANR01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/TANR01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with TANR01RR
# Pulling data forGENE04RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/GENE04RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with GENE04RR
# Pulling data forGENE03RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/GENE03RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with GENE03RR
# Pulling data forGENE02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/GENE02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with GENE02RR
# Pulling data forGENE01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/GENE01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with GENE01RR
# Pulling data forREVT03RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/REVT03RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with REVT03RR
# Pulling data forREVT02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/REVT02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with REVT02RR
# Pulling data forCALF03RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/CALF03RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with CALF03RR
# Pulling data forCALF01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/CALF01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with CALF01RR
# Pulling data forREVT01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/REVT01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with REVT01RR
# Pulling data forDELV02RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DELV02RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DELV02RR
# Pulling data forDELV01RR
# Fetching metadata from: https://service.rvdata.us/api/fileset/cruise_id/DELV01RR
# Successfully fetched metadata. Top-level keys: dict_keys(['status', 'status_message', 'data'])
# Ran into an issue with DELV01RR

# %%
cruise_id
